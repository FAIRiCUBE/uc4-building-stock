# %%
import geopandas as gpd
import pandas as pd
import osmnx as ox
from shapely.geometry import LineString, Point, Polygon, MultiPolygon , GeometryCollection
from shapely.ops import unary_union

import pyproj
from pyproj import Transformer

import numpy as np
import matplotlib.pyplot as plt
import fiona
import rasterio
from rasterio.plot import show, show_hist
from rasterio.merge import merge
from rasterio.windows import WindowError

import PIL
from PIL import Image, ImageTk, ImageDraw

from rasterio.transform import Affine
from rasterio.mask import mask
from rasterio.crs import CRS  # Import CRS from rasterio.crs
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

from scipy.ndimage import zoom

import xml.etree.ElementTree as ET

import zipfile

import os 

idx = pd.IndexSlice

# %%
upath = r'../data'

# %%
def extract_specific_rooftype_height_and_geometry(gml_file, specific_rooftype):
    # Parse the CityGML file
    tree = ET.parse(gml_file)
    root = tree.getroot()

    # Namespace mapping for CityGML
    ns = {
        'citygml': 'http://www.opengis.net/citygml/1.0',
        'building': 'http://www.opengis.net/citygml/building/1.0',
        'gml': 'http://www.opengis.net/gml'
    }

    # List to store buildings with the specific rooftop type
    buildings_info = []

    # Find all buildings
    for building in root.findall('.//building:Building', ns):
        roof_type_elem = building.find('.//building:roofType', ns)
        
        if roof_type_elem is not None and roof_type_elem.text.lower() == specific_rooftype.lower():
            object_id = building.get('{http://www.opengis.net/gml}id', 'Unknown ID')
            
            height_elem = building.find('.//building:measuredHeight', ns)
            height = float(height_elem.text) if height_elem is not None else 'Unknown height'
            
            # Extract geometry
            geometrylist = []
            for polygon_elem in building.findall('.//gml:Polygon', ns):
                exterior_elem = polygon_elem.find('gml:exterior/gml:LinearRing', namespaces=ns)
                if exterior_elem is not None:
                    pos_list_elem = exterior_elem.find('gml:posList', namespaces=ns)
                    if pos_list_elem is not None:
                        coords_str = pos_list_elem.text.strip()
                        coords_list = coords_str.split()
                        coords = []
                        for i in range(0, len(coords_list), 3):  # Assuming 3D coordinates (x, y, z)
                            x = float(coords_list[i])
                            y = float(coords_list[i+1])
                            z = float(coords_list[i+2])
                            coords.append((x, y, z))
                        polygon_geom = Polygon(coords)
                        if not polygon_geom.is_valid:
                            polygon_geom = polygon_geom.buffer(0)  # Fix invalid geometries
                        if polygon_geom.is_valid:
                            geometrylist.append(polygon_geom)
                        
                        
            if geometrylist:
                geometry = unary_union(geometrylist)
            else:
                geometry = None

            buildings_info.append({
                'object_id': object_id,
                'height': height,
                'geometry': geometry
            })

    # Create a DataFrame from the extracted information
    df = gpd.GeoDataFrame(buildings_info)

    return df

# %%
def dissolve_polygons(buildings_3d):
    data_list = []

    # Iterate through each row in buildings_3d
    for index, row in buildings_3d.iterrows():
        all_parts = []

        # Iterate through each polygon geometry in the row
        for geom in row['geometry']:
            # Convert 3D to 2D
            exterior_coords = list(geom.exterior.coords.xy)
            polygon_part = Polygon(zip(exterior_coords[0], exterior_coords[1]))
            all_parts.append(polygon_part)

        # Create a GeometryCollection from all parts
        geom_collection = GeometryCollection(all_parts)

        try:
            # Union all parts to create a single Polygon
            dissolved_polygon = unary_union(geom_collection)
        except Exception as e:
            print(f"Error during union operation: {e}")
            continue  # Skip this geometry if union fails

        # Append dissolved polygon and object_id to data_list
        data_list.append({
            'geometry': dissolved_polygon,
            'object_id': row['object_id']  # Assuming 'object_id' is a column in buildings_3d
        })

    # Create a GeoDataFrame from the data list
    gdf = gpd.GeoDataFrame(data_list, geometry='geometry')

    return gdf

# %%
# %%time
# Extract information for buildings with specific rooftop type (e.g., "satteldach")
specific_rooftype = "SATTELDACH"

# List to store paths .gml as well as 3D and 2D polygon  files
df_buildings_3d = gpd.GeoDataFrame()
df_buildings_2d = gpd.GeoDataFrame()

dir_path = os.path.join(upath, r'Vienna/LOD2.1/unzip')

# Iterate over files in the directory
for fn in os.listdir(dir_path):
    file_path = os.path.join(dir_path, fn)
    if os.path.isfile(file_path) and fn.lower().endswith('.gml'):
        #print(fn)
        
        # Extract specific rooftype height and geometry
        buildings_3d = extract_specific_rooftype_height_and_geometry(file_path, specific_rooftype)
        print(buildings_3d.head())
        #buildings_3d.reset_index(drop=True).to_csv(os.path.join(upath, r'Vienna/modelling_results/building_3d_TEST.csv'))
        if buildings_3d is not None and not buildings_3d.empty:
            # Concatenate the 3D buildings
            df_buildings_3d = pd.concat([df_buildings_3d, buildings_3d])

            # Convert 3D buildings to 2D and concatenate
            # try:
            #     buildings_2d = dissolve_polygons(buildings_3d)
            #     df_buildings_2d = pd.concat([df_buildings_2d, buildings_2d])
            # except ValueError as e:
            #     print(f"Error converting {fn} to 2D: {e}")
        else:
            print(f"No data for specific rooftype in file {fn}")
            
# Save to file            
df_buildings_3d.reset_index(drop=True).to_csv(os.path.join(upath, r'Vienna/modelling_results/building_3d_2_1.csv'))
#df_buildings_2d.reset_index(drop=True).to_file(os.path.join(upath, r'Vienna/modelling_results/building_2d_2.json'), driver='GeoJSON')
# Out:
#                                   object_id  height
# 0  UUID_LOD2_034769-15982479-db49-4af1-b7a3    4.18  \
#
#                                             geometry
# 0  POLYGON Z ((-10281.051 336476.089 239.507, -10...
#                                   object_id  height
# 0  UUID_LOD2_043498-5ce690b4-7be3-470a-8084    8.49  \
# 1  UUID_LOD2_092812-338cbe26-e65c-4bde-bcbd    9.21
# 2  UUID_LOD2_097704-593799f2-a8cb-4de7-8e74    7.31
# 3  UUID_LOD2_103166-6c75acd8-c5b0-465c-8bdf    6.02
# 4  UUID_LOD2_103166-de1edcf4-4449-4f70-995a    8.58
#
#                                             geometry
# 0  POLYGON Z ((-10198.134 342927.052 270.66, -101...
# 1  POLYGON Z ((-10280.519 342900 260.79, -10281.2...
# 2  POLYGON Z ((-10402.482 342889.534 269.4, -1040...
# 3  POLYGON Z ((-10212.579 342807.396 292.41, -102...
# 4  POLYGON Z ((-10186.772 342864.624 281.6, -1018...
#                                   object_id  height
# 0  UUID_LOD2_043488-5d480ad9-197f-4984-9776    7.00  \
# 1  UUID_LOD2_043489-cb32a512-d6fa-43d6-a546   11.55
# 2  UUID_LOD2_043494-23e1f5e0-dd44-4cda-8617   10.20
# 3  UUID_LOD2_043588-d5ee057c-8b07-4885-99e8    8.26
# 4  UUID_LOD2_096219-11cd972d-ee6e-440e-87a4    8.22
#
#                                             geometry
# 0  POLYGON Z ((-10365.343 343085.679 185.388, -10...
# 1  POLYGON Z ((-10383.13 343074.48 189.993, -1037...
# 2  POLYGON Z ((-10231.571 343223.725 189.103, -10...
# 3  POLYGON Z ((-10038.72 343352.011 159.06, -1004...
# 4  POLYGON Z ((-10052.265 343414.106 138.15, -100...
#                                   object_id  height
# 0  UUID_LOD2_A01620-09bbb821-2832-4ca4-a44d    3.44  \
#
#                                             geometry
# 0  POLYGON Z ((-10257.985 343880.447 105.52, -102...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 079088.gml
#                                   object_id  height
# 0  UUID_LOD2_182323-48161a73-c8e9-4dec-b383    3.89  \
# 1  UUID_LOD2_188765-d511000b-53a5-4729-be0e    6.54
# 2  UUID_LOD2_200939-ea437924-762c-4ba1-b7ca    9.17
# 3  UUID_LOD2_501181-78b1f4a4-9081-4065-b940    3.49
# 4  UUID_LOD2_A01619-59115b82-cc55-4f56-b8a2    9.58
#
#                                             geometry
# 0  POLYGON Z ((-10248.102 344987.603 131.86, -102...
# 1  POLYGON Z ((-10210.755 344966.388 135.724, -10...
# 2  POLYGON Z ((-10271.736 344974.93 135.014, -102...
# 3  POLYGON Z ((-10254.075 344912.185 130.65, -102...
# 4  POLYGON Z ((-10239.146 344871.557 132.741, -10...
#                                   object_id  height
# 0  UUID_LOD2_043506-980552cc-b2ac-4ad6-b7a9    6.47  \
# 1  UUID_LOD2_043506-a13cc459-50bd-472b-9088    7.44
# 2  UUID_LOD2_043581-ed1f0b4a-28da-4868-b054   11.70
# 3  UUID_LOD2_043587-d7caed63-128c-4ea1-aa87    6.38
# 4  UUID_LOD2_104592-8f3d3857-8813-4578-8001    6.15
#
#                                             geometry
# 0  POLYGON Z ((-10087.635 345343.26 145.66, -1009...
# 1  POLYGON Z ((-10095.849 345388.006 145.303, -10...
# 2  POLYGON Z ((-10196.35 345062.99 134.78, -10194...
# 3  POLYGON Z ((-10150.61 345151.34 144.577, -1014...
# 4  POLYGON Z ((-10266 345012.704 129.24, -10266.0...
#                                   object_id  height
# 0  UUID_LOD2_043507-ee400495-e6c5-4202-a0c2    9.14  \
# 1  UUID_LOD2_043580-f6c8ccbc-4fb8-42f7-afb2    7.05
# 2  UUID_LOD2_043586-d8ef78cd-b443-4252-a7c7    7.44
# 3  UUID_LOD2_043586-f93e085b-4bca-498d-b5a9    7.96
# 4  UUID_LOD2_119158-579ce8d8-de6c-417f-b28d    6.89
#
#                                             geometry
# 0  POLYGON Z ((-10077.957 345552.341 153.99, -100...
# 1  POLYGON Z ((-10096.74 345524.9 142.65, -10095....
# 2  POLYGON Z ((-10067.96 345698.472 162.21, -1007...
# 3  POLYGON Z ((-10078.13 345668.24 156.51, -10076...
# 4  POLYGON Z ((-10076.655 345658.41 163.81, -1007...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 080073.gml
#                                   object_id  height
# 0  UUID_LOD2_A02611-fa1240dd-4c4b-4066-aa50    6.01  \
#
#                                             geometry
# 0  POLYGON Z ((-9719.15 337832.298 250.01, -9717....
#                                   object_id  height
# 0  UUID_LOD2_042981-0aebd048-8692-4efe-8712   12.01  \
# 1  UUID_LOD2_042987-dc671969-ae9f-4ee4-a160    6.08
# 2  UUID_LOD2_042989-ab45865e-49f3-47d0-be4e    4.31
# 3  UUID_LOD2_043005-f3f62970-2df4-4628-b18b    3.46
# 4  UUID_LOD2_043007-0101352a-caa5-444d-a83e    9.49
#
#                                             geometry
# 0  POLYGON Z ((-9602.82 340708.791 79.39, -9603.0...
# 1  POLYGON Z ((-9620.507 340709.866 80.46, -9621....
# 2  POLYGON Z ((-9629.339 340685.124 92, -9630.59 ...
# 3  POLYGON Z ((-9516.865 340796.828 82.67, -9517....
# 4  POLYGON Z ((-9564.564 340800.592 86.145, -9565...
#                                   object_id  height
# 0  UUID_LOD2_043391-5351edae-740f-4bbe-812b    3.30  \
# 1  UUID_LOD2_043392-851e5245-0791-4441-9737   10.71
# 2  UUID_LOD2_104314-e8f059bd-0a27-4382-9fdb    6.26
# 3  UUID_LOD2_104316-26ef6b0f-81dd-4084-baf5    3.06
# 4  UUID_LOD2_104316-d8d4491f-ad14-4b19-8d08    4.38
#
#                                             geometry
# 0  POLYGON Z ((-9751.949 341607.057 106.84, -9751...
# 1  POLYGON Z ((-9768.432 341643.668 118.032, -977...
# 2  POLYGON Z ((-9526.64 341558.3 94.433, -9522.97...
# 3  POLYGON Z ((-9662.665 341589.01 104.2, -9664.5...
# 4  POLYGON Z ((-9666.7 341616.02 101.97, -9666.34...
#                                   object_id  height
# 0  UUID_LOD2_043477-e0541781-bb9c-4c40-9009    7.11  \
# 1  UUID_LOD2_043483-32c6e91c-828f-4c44-b165    4.96
# 2  UUID_LOD2_043484-a031e913-ba13-4182-a53b   10.25
# 3  UUID_LOD2_043499-ca050f53-5694-461a-8be8   10.55
# 4  UUID_LOD2_043527-f8fbbd71-b2f5-4622-8b58    8.21
#
#                                             geometry
# 0  POLYGON Z ((-9747.395 343411.028 102.598, -974...
# 1  POLYGON Z ((-9555.41 343308.39 95.21, -9554.16...
# 2  POLYGON Z ((-9571.976 343311.482 105.04, -9576...
# 3  POLYGON Z ((-9985.08 343257.67 167.71, -9990.9...
# 4  POLYGON Z ((-9525.97 343329.34 99.852, -9523.3...
#                                   object_id  height
# 0  UUID_LOD2_043559-04c3df55-0082-4997-b772    8.22  \
# 1  UUID_LOD2_043560-752b2a9b-2055-4bdf-bae3    7.34
# 2  UUID_LOD2_043570-d0a32630-3b5c-43eb-906e    6.64
# 3  UUID_LOD2_043572-3620c3f7-454a-4f54-98ec    7.71
# 4  UUID_LOD2_043572-a458cdc1-2205-4424-b729   11.75
#
#                                             geometry
# 0  POLYGON Z ((-9770.81 343570.355 111.47, -9775....
# 1  POLYGON Z ((-9827.96 343615.559 114.92, -9824....
# 2  POLYGON Z ((-9870.47 343712.17 108.322, -9870....
# 3  POLYGON Z ((-9819.15 343943.81 110.31, -9825.3...
# 4  POLYGON Z ((-9898.3 343924 124.107, -9896.935 ...
#                                   object_id  height
# 0  UUID_LOD2_111600-02af5369-adf0-4bf7-999f   15.48  \
# 1  UUID_LOD2_226542-2566367e-f431-4d6b-85c6    8.06
#
#                                             geometry
# 0  POLYGON Z ((-9671.65 344272.53 142.133, -9673....
# 1  POLYGON Z ((-9664.51 344202.82 126.356, -9663....
#                                   object_id  height
# 0  UUID_LOD2_043511-4f9bb1ee-bcff-4d9d-b496    8.66  \
# 1  UUID_LOD2_119166-31021aae-e1ef-40a4-9ba5    4.57
# 2  UUID_LOD2_131117-dbad3444-1ba4-45e1-8d35    5.22
# 3  UUID_LOD2_174086-80590dd1-4b05-429f-a6a0    3.64
# 4  UUID_LOD2_188116-2c0ae082-0df5-4169-9474    8.84
#
#                                             geometry
# 0  POLYGON Z ((-9951.86 345541.58 174.72, -9950.2...
# 1  POLYGON Z ((-9896.425 345670.617 188.14, -9895...
# 2  POLYGON Z ((-9998.2 345565.35 171.914, -9996.7...
# 3  POLYGON Z ((-9934.35 345524.03 172.36, -9934.0...
# 4  POLYGON Z ((-9979.613 345647.753 178.968, -998...
#                                   object_id  height
# 0  UUID_LOD2_501207-c64f8eae-1475-4bd7-ba2e    4.92  \
#
#                                             geometry
# 0  POLYGON Z ((-9793.295 346121.8 171.44, -9793.2...
#                                   object_id  height
# 0  UUID_LOD2_043032-57222e66-f5a4-42ec-945d    9.84  \
# 1  UUID_LOD2_043035-55df29ad-5a79-43ba-bedc    5.25
# 2  UUID_LOD2_043035-8ef6cf40-6d2e-4bef-b681    3.63
# 3  UUID_LOD2_099580-de31283d-8a77-456a-bfb3    4.55
#
#                                             geometry
# 0  POLYGON Z ((-9359.4 340459.94 121.934, -9359.3...
# 1  POLYGON Z ((-9309.64 340485.86 120.97, -9310.2...
# 2  POLYGON Z ((-9317.24 340463.13 115.93, -9316.9...
# 3  POLYGON Z ((-9379.197 340497.824 124.57, -9378...
#                                   object_id  height
# 0  UUID_LOD2_042962-dc0c7e3b-3967-4254-9f24    6.04  \
# 1  UUID_LOD2_042971-65e0869a-4850-4533-8854    7.92
# 2  UUID_LOD2_042999-ebca109f-46c6-4903-9b05    7.92
# 3  UUID_LOD2_043024-d5dfd2e6-ecd3-4ddb-b882    3.47
# 4  UUID_LOD2_043028-6997ca6c-cd73-4094-af78   11.68
#
#                                             geometry
# 0  POLYGON Z ((-9183.906 341004.854 83.29, -9186....
# 1  MULTIPOLYGON Z (((-9452.85 340765.53 82.42, -9...
# 2  POLYGON Z ((-9344.762 340858.593 84.497, -9347...
# 3  POLYGON Z ((-9444.131 340496.252 112.79, -9445...
# 4  POLYGON Z ((-9397.29 340529.49 124.714, -9395....
#                                   object_id  height
# 0  UUID_LOD2_042961-5e845214-5caf-4b0a-a122   11.54  \
# 1  UUID_LOD2_042978-29b30d2b-91f1-45ed-9dcc    3.45
# 2  UUID_LOD2_042978-30bdf593-edf0-4144-b831    4.26
# 3  UUID_LOD2_042980-ea29b1aa-d4b6-41fd-a67b    3.03
# 4  UUID_LOD2_042984-afbfe0da-155d-425b-904a   12.24
#
#                                             geometry
# 0  POLYGON Z ((-9101.06 341086.22 87.077, -9095.7...
# 1  POLYGON Z ((-9089.568 341157.145 78.013, -9087...
# 2  POLYGON Z ((-9058.795 341159.691 79.12, -9058....
# 3  POLYGON Z ((-9111.8 341183.23 72.69, -9111.001...
# 4  POLYGON Z ((-9147.267 341132.558 85.97, -9150....
#                                   object_id  height
# 0  UUID_LOD2_043343-c9a1ccff-5c4a-4d45-bbfa    4.05  \
# 1  UUID_LOD2_043345-a23bb3ff-ca08-4466-8d88    2.39
# 2  UUID_LOD2_043351-11f10b10-5dd2-4bfd-87cc    4.89
# 3  UUID_LOD2_099017-48315e29-5002-433e-841d    5.63
# 4  UUID_LOD2_132395-16363e66-8226-4d30-956a    8.14
#
#                                             geometry
# 0  MULTIPOLYGON Z (((-9050.842 341527.867 116.282...
# 1  POLYGON Z ((-9099.27 341555.09 117.217, -9099....
# 2  POLYGON Z ((-9212.61 341529.41 119.665, -9211....
# 3  POLYGON Z ((-9256.53 341573.27 118.71, -9256.3...
# 4  POLYGON Z ((-9109.85 341524.279 119.16, -9113....
#                                   object_id  height
# 0  UUID_LOD2_043512-1aa9e21e-4792-48ca-80f6    0.58  \
# 1  UUID_LOD2_043512-84c111cc-8f9c-4829-ac81    5.80
# 2  UUID_LOD2_074325-439299ae-66ca-4f8d-955c    4.08
# 3  UUID_LOD2_074325-4434829e-13fe-410c-bc42    8.03
# 4  UUID_LOD2_099291-1e74b5e7-d516-42ba-9a6f    9.13
#
#                                             geometry
# 0  POLYGON Z ((-9186.33 342859.08 91.02, -9174.94...
# 1  MULTIPOLYGON Z (((-9153.82 342879.15 91.2, -91...
# 2  POLYGON Z ((-9134.464 342964.961 96.77, -9135....
# 3  POLYGON Z ((-9125.345 342966.033 101.045, -912...
# 4  POLYGON Z ((-9191.52 342981.89 95.67, -9193.7 ...
#                                   object_id  height
# 0  UUID_LOD2_043478-768fde8f-ae23-4141-a38f   10.52  \
# 1  UUID_LOD2_043480-94276196-ef05-49aa-b245    9.61
# 2  UUID_LOD2_043516-da9ebbcf-cf4b-450c-8466    4.02
# 3  UUID_LOD2_043521-69b9b724-981b-4a43-b59a    3.93
# 4  UUID_LOD2_043522-6c6bd6ba-c840-458c-8e13    5.20
#
#                                             geometry
# 0  POLYGON Z ((-9468.378 343238.763 103.88, -9472...
# 1  POLYGON Z ((-9495.593 343257.07 103.17, -9500 ...
# 2  POLYGON Z ((-9264.47 343009.087 94.99, -9266.0...
# 3  POLYGON Z ((-9347.16 343161.628 95.421, -9348....
# 4  POLYGON Z ((-9367.296 343182.573 92.89, -9366....
#                                   object_id  height
# 0  UUID_LOD2_092212-10629ccf-d440-4ff9-a6a8    8.03  \
# 1  UUID_LOD2_092212-31386d67-9af4-4f8f-85ba    4.88
# 2  UUID_LOD2_111601-ec1e0524-52ce-474c-ae26    8.00
#
#                                             geometry
# 0  POLYGON Z ((-9153.5 345049.13 197.206, -9147.4...
# 1  POLYGON Z ((-9181.9 344849.401 154.33, -9182.6...
# 2  POLYGON Z ((-9344.8 344767.15 145.35, -9341.09...
#                                   object_id  height
# 0  UUID_LOD2_043573-f62916b1-17a0-4fb1-9f63    5.56  \
#
#                                             geometry
# 0  POLYGON Z ((-9027.79 344924.034 160.958, -9029...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 082063.gml
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 082069.gml
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 082071.gml
#                                   object_id  height
# 0  UUID_LOD2_A02603-fb158fbf-4d8e-45a4-95f6    8.74  \
#
#                                             geometry
# 0  POLYGON Z ((-8966.901 339870.428 113.11, -8973...
#                                   object_id  height
# 0  UUID_LOD2_043432-e03686d7-181a-4012-a50b    9.59  \
#
#                                             geometry
# 0  POLYGON Z ((-8787.193 340976.462 78.985, -8783...
#                                   object_id  height
# 0  UUID_LOD2_042957-3300a5c9-728b-4e36-81d8   13.95  \
# 1  UUID_LOD2_043040-efefc0a9-702e-49fb-bb7f   11.50
# 2  UUID_LOD2_043042-04ff0500-a426-4003-bfc2   10.22
# 3  UUID_LOD2_043312-f84b4037-dd58-4c86-97d3   11.93
# 4  UUID_LOD2_043319-7c4850ea-ed28-41ce-9eb2   10.53
#
#                                             geometry
# 0  POLYGON Z ((-8983.79 341137.54 74.441, -8980.8...
# 1  POLYGON Z ((-8950.489 341074.986 74.452, -8952...
# 2  POLYGON Z ((-8980.659 341061.373 82.41, -8979....
# 3  POLYGON Z ((-8637.588 341440.03 102.513, -8642...
# 4  POLYGON Z ((-8761.38 341466.945 103.434, -8761...
#                                   object_id  height
# 0  UUID_LOD2_043330-a6abefa5-542e-4815-9dc1   17.91  \
# 1  UUID_LOD2_043332-aa3e4d32-c71d-40c8-840f    5.38
# 2  UUID_LOD2_043332-c95d9d11-9260-439b-848e    5.82
# 3  UUID_LOD2_043333-5881eaf2-6b1e-4acc-b42f    6.07
# 4  UUID_LOD2_043333-ad37a69a-b7a9-43d9-9810    7.67
#
#                                             geometry
# 0  POLYGON Z ((-8723.933 341501.226 113.389, -872...
# 1  POLYGON Z ((-8761.94 341594.64 125.805, -8761....
# 2  POLYGON Z ((-8777.64 341595.44 126.032, -8777....
# 3  POLYGON Z ((-8785.57 341596.505 127.73, -8787....
# 4  POLYGON Z ((-8808.37 341527.97 109.63, -8807.5...
#                                   object_id  height
# 0  UUID_LOD2_099293-15558667-f606-40e9-ab81    6.43  \
#
#                                             geometry
# 0  POLYGON Z ((-8511.644 342241.934 83.948, -8511...
#                                   object_id  height
# 0  UUID_LOD2_043562-9439aa2a-8229-4f11-b08c    8.35  \
#
#                                             geometry
# 0  POLYGON Z ((-8778.86 344496.684 299.27, -8776....
#                                   object_id  height
# 0  UUID_LOD2_043485-8494305a-8541-4ab2-94c3    7.97  \
# 1  UUID_LOD2_043501-cfe62e7a-cdbf-4420-a5ab    8.45
# 2  UUID_LOD2_043503-8cfc2adc-3c20-4241-ae40    9.63
# 3  UUID_LOD2_043595-091268b6-8d48-41d1-afde   10.62
# 4  UUID_LOD2_104661-0c695f1a-ff19-45c2-b459    8.44
#
#                                             geometry
# 0  POLYGON Z ((-8581.03 345401.66 221.49, -8581.0...
# 1  POLYGON Z ((-8667.165 345365.393 222.818, -866...
# 2  POLYGON Z ((-8533.86 345428.58 231.168, -8532....
# 3  POLYGON Z ((-8587.368 345305.228 214.04, -8583...
# 4  POLYGON Z ((-8612.587 345371.051 228.53, -8617...
#                                   object_id  height
# 0  UUID_LOD2_043597-7d7918e6-1c93-41d4-b81a    7.99  \
# 1  UUID_LOD2_134204-206cce0c-471c-41e3-88e9    6.54
# 2  UUID_LOD2_134204-221c849f-c609-4f0a-91c9    3.09
#
#                                             geometry
# 0  POLYGON Z ((-8528.477 345544.839 260.94, -8530...
# 1  POLYGON Z ((-8573.011 345500.595 244.987, -857...
# 2  POLYGON Z ((-8598.682 345509.478 244.941, -860...
#                                   object_id  height
# 0  UUID_LOD2_128357-35cda44f-891f-4b47-b37c    3.24  \
#
#                                             geometry
# 0  POLYGON Z ((-7903.12 332068.72 173.498, -7901....
#                                   object_id  height
# 0  UUID_LOD2_090736-b6b774e9-8aa3-49cc-8bfc    3.28  \
# 1  UUID_LOD2_090740-236191ec-aed7-4aa3-91e9   12.12
# 2  UUID_LOD2_146866-eac17144-6dbc-4850-9533    8.54
# 3  UUID_LOD2_146868-9d477778-4846-486a-827d    5.94
# 4  UUID_LOD2_146868-a2e0ce8f-cb08-4e01-be3e    7.36
#
#                                             geometry
# 0  POLYGON Z ((-8171.33 333016.33 109.96, -8168.6...
# 1  POLYGON Z ((-8216.91 333050.682 114.757, -8216...
# 2  POLYGON Z ((-8130.2 333046.56 110.004, -8141.9...
# 3  POLYGON Z ((-8275.024 333075.412 111.89, -8274...
# 4  POLYGON Z ((-8250.65 333076.81 109.576, -8246....
#                                   object_id  height
# 0  UUID_LOD2_034770-f0d40101-0fc3-45b9-ae99    4.08  \
#
#                                             geometry
# 0  POLYGON Z ((-8163.62 335023.53 139.35, -8163.7...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 083073.gml
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 083076.gml
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 083081.gml
#                                   object_id  height
# 0  UUID_LOD2_032622-68ea7f77-4c45-40c3-bddd    6.27  \
# 1  UUID_LOD2_043179-a23d92bd-1f65-438b-81fc   16.01
# 2  UUID_LOD2_043182-e6bb8162-dbf6-4a2f-9ded   13.17
# 3  UUID_LOD2_043186-66cd620a-57f8-4494-bbca    5.08
# 4  UUID_LOD2_043208-009d8585-9196-46f2-aae6   14.85
#
#                                             geometry
# 0  POLYGON Z ((-8301.687 341449.901 82.378, -8301...
# 1  POLYGON Z ((-8022.627 341258.634 70.26, -8021....
# 2  POLYGON Z ((-8029.442 341229.624 83.658, -8030...
# 3  POLYGON Z ((-8112.345 341264.889 71.416, -8118...
# 4  POLYGON Z ((-8090.69 341181.17 79.986, -8089.1...
#                                   object_id  height
# 0  UUID_LOD2_043148-30ef8ed1-c953-4458-b7e6    8.95  \
# 1  UUID_LOD2_043151-1fb938c8-25ff-49e1-8848   12.75
# 2  UUID_LOD2_043152-f5f4177c-19b9-4a98-aa01    3.82
# 3  UUID_LOD2_043154-a92facfc-ac24-430b-bf38   15.98
# 4  UUID_LOD2_043287-fe3f1ebf-bfec-4642-a5a6   10.60
#
#                                             geometry
# 0  POLYGON Z ((-8041.105 341849.509 102.692, -804...
# 1  MULTIPOLYGON Z (((-8054.821 341920.683 110.55,...
# 2  POLYGON Z ((-8066.485 341943.172 108.328, -806...
# 3  POLYGON Z ((-8074.026 341981.912 119.125, -807...
# 4  POLYGON Z ((-8423.56 341553.12 113.151, -8423....
#                                   object_id  height
# 0  UUID_LOD2_043101-a7d476ce-74b3-401c-be5b    9.94  \
# 1  UUID_LOD2_098795-ae3441ed-8b62-46f6-9acf   10.72
# 2  UUID_LOD2_113558-9324098a-970d-4433-a1d9    9.82
# 3  UUID_LOD2_113572-499ca30a-4b4c-4917-95bb   10.43
#
#                                             geometry
# 0  POLYGON Z ((-8012.45 342089.48 110.32, -8012.3...
# 1  POLYGON Z ((-8044.939 342074.058 122.977, -805...
# 2  MULTIPOLYGON Z (((-8009.93 342193.48 118.75, -...
# 3  POLYGON Z ((-8025.489 342126.644 118.32, -8025...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 083089.gml
#                                   object_id  height
# 0  UUID_LOD2_043504-618c74e9-9787-4d64-915c   12.89  \
# 1  UUID_LOD2_094942-64cb580b-d0d0-4a8e-9d2f    9.40
# 2  UUID_LOD2_117976-27b0d0a6-fd7a-48f5-9e4b   11.17
# 3  UUID_LOD2_130391-b47e03d5-6e79-4f99-8ca8    5.31
# 4  UUID_LOD2_146368-90a840fd-83a3-4f30-8886   10.86
#
#                                             geometry
# 0  POLYGON Z ((-8475.865 345427.199 218.463, -847...
# 1  POLYGON Z ((-8445.421 345371.038 213.85, -8448...
# 2  POLYGON Z ((-8389.99 345417.1 205.68, -8387.24...
# 3  POLYGON Z ((-8481.29 345481.93 237.968, -8478....
# 4  POLYGON Z ((-8438.994 345376.338 215.6, -8441....
#                                   object_id  height
# 0  UUID_LOD2_043486-381ea77f-a5b1-4b07-afda    8.36  \
# 1  UUID_LOD2_093569-c8d53c71-8b65-44c6-8f62   10.23
# 2  UUID_LOD2_109959-7b566b1c-d8b9-4e66-8ab2    7.97
# 3  UUID_LOD2_113657-3e315c03-dd41-42d0-bf3d   10.22
# 4  UUID_LOD2_130535-2b31ce44-da39-4004-b4d0   10.74
#
#                                             geometry
# 0  POLYGON Z ((-8474.96 345574.06 259.063, -8469....
# 1  POLYGON Z ((-8429.64 345643.93 246.207, -8426....
# 2  POLYGON Z ((-8395.434 345614.623 242.552, -840...
# 3  POLYGON Z ((-8489.585 345520.302 254.37, -8493...
# 4  POLYGON Z ((-8449.42 345588.41 257.667, -8446....
#                                   object_id  height
# 0  UUID_LOD2_085399-f76375fa-2674-4328-b84a   15.36  \
# 1  UUID_LOD2_208375-b8b218c6-14c5-46e1-a664   14.46
#
#                                             geometry
# 0  POLYGON Z ((-7696.204 332158.616 161.96, -7698...
# 1  POLYGON Z ((-7671.57 332161.374 161.35, -7673....
#                                   object_id  height
# 0  UUID_LOD2_090677-0eb9409f-54d3-40fa-a124    8.34  \
# 1  UUID_LOD2_090733-68c48dd8-216e-4c01-aca1    7.28
# 2  UUID_LOD2_090739-40d68eb1-8fd5-4a38-b9a3    3.19
# 3  UUID_LOD2_095358-b1d0c8f0-5dda-465c-afd1    5.71
# 4  UUID_LOD2_104326-17dee35e-d16c-4ac5-a07b    4.95
#
#                                             geometry
# 0  POLYGON Z ((-7599.48 333245.22 105.826, -7592....
# 1  POLYGON Z ((-7543.603 333182.48 107.33, -7541....
# 2  POLYGON Z ((-7707.4 333182.26 101.46, -7704.79...
# 3  POLYGON Z ((-7704.59 333117.41 101.46, -7702.5...
# 4  POLYGON Z ((-7564.605 333177.025 105.21, -7564...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 084067.gml
#                                   object_id  height
# 0  UUID_LOD2_085524-93891c3b-650b-4a24-b17a    2.66  \
# 1  UUID_LOD2_085525-aa01bfdf-9258-4fe0-9cc1    4.86
#
#                                             geometry
# 0  POLYGON Z ((-7558.09 334283.04 115.43, -7555.9...
# 1  POLYGON Z ((-7611.08 334447.5 121.466, -7608.3...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 084069.gml
#                                   object_id  height
# 0  UUID_LOD2_085071-f8d2d09f-822f-4240-a4e1    4.81  \
#
#                                             geometry
# 0  POLYGON Z ((-7506.532 335952.496 185.44, -7507...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 084075.gml
#                                   object_id  height
# 0  UUID_LOD2_A02606-b8f1515b-147d-4da6-bd18    2.98  \
#
#                                             geometry
# 0  POLYGON Z ((-7657.44 339009.67 107.83, -7658.4...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 084080.gml
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 084081.gml
#                                   object_id  height
# 0  UUID_LOD2_043189-c830861d-db91-4578-8395    3.59  \
# 1  UUID_LOD2_043189-ece92384-9d79-40f7-8fc0   18.14
# 2  UUID_LOD2_043194-cf2bc9c3-0d21-4cdb-bba8    2.77
# 3  UUID_LOD2_043194-d8a125c5-a14a-45a6-9365   10.38
# 4  UUID_LOD2_043220-35557e40-5de4-44ac-b235    7.91
#
#                                             geometry
# 0  POLYGON Z ((-7486.92 340914.24 71.71, -7487.03...
# 1  POLYGON Z ((-7678.376 340996.791 77.315, -7679...
# 2  MULTIPOLYGON Z (((-7903.15 341036.02 68.43, -7...
# 3  POLYGON Z ((-7878.92 341071.091 73.95, -7881.0...
# 4  POLYGON Z ((-7923.28 341151.814 76.1, -7920.29...
#                                   object_id  height
# 0  UUID_LOD2_042013-939d2b01-20cd-4cfb-8abc   11.63  \
# 1  UUID_LOD2_042014-0f09cf9b-ad2d-422c-b45a    3.87
# 2  UUID_LOD2_042014-9b7f73c6-a767-474d-a831    9.78
# 3  UUID_LOD2_043064-c2b5c396-5aab-4898-be00    9.74
# 4  UUID_LOD2_043065-1efa38d9-b768-4fc4-a5d5    4.49
#
#                                             geometry
# 0  POLYGON Z ((-7596.11 341569.78 74.2, -7596.76 ...
# 1  POLYGON Z ((-7601.61 341591.47 74.442, -7599.6...
# 2  POLYGON Z ((-7613.52 341578.85 74.26, -7611.67...
# 3  POLYGON Z ((-7897.961 341880.491 94.506, -7897...
# 4  POLYGON Z ((-7883.87 341924.93 92.847, -7881.7...
#                                   object_id  height
# 0  UUID_LOD2_043104-6356268d-1513-4989-abf5    9.76  \
# 1  UUID_LOD2_043116-e94d70f7-b720-4191-a36c    8.35
# 2  UUID_LOD2_043145-3df3ca12-2702-4f84-9f8b    3.95
# 3  UUID_LOD2_097008-1f82ea1a-e7ef-48b7-adaa   10.40
# 4  UUID_LOD2_107838-dafa3ad7-00d1-40b8-9821    5.97
#
#                                             geometry
# 0  POLYGON Z ((-7752.22 342206.9 109.83, -7747.56...
# 1  POLYGON Z ((-7549.082 342008.71 98.5, -7549.19...
# 2  POLYGON Z ((-7693.45 342079.55 98.07, -7693.61...
# 3  POLYGON Z ((-7750.79 342113.15 103.391, -7750....
# 4  POLYGON Z ((-7536.926 342075.435 102.1, -7537....
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 084087.gml
#                                   object_id  height
# 0  UUID_LOD2_094945-46832cda-425f-4e57-8b44    2.59  \
# 1  UUID_LOD2_094945-a120aaef-4466-494d-a814   14.34
# 2  UUID_LOD2_094945-fcf20079-af60-4e57-a039    6.82
#
#                                             geometry
# 0  POLYGON Z ((-7576.07 345425.32 319.23, -7574.5...
# 1  POLYGON Z ((-7554.088 345381.509 327.423, -755...
# 2  POLYGON Z ((-7509.45 345492.11 319.52, -7506.4...
#                                   object_id  height
# 0  UUID_LOD2_085421-606b6f9a-0de9-467f-8755    3.63  \
# 1  UUID_LOD2_085422-418f15a8-6ecf-487b-8f47   10.08
# 2  UUID_LOD2_085423-f7902d56-7990-4557-9532    3.76
# 3  UUID_LOD2_085424-b3a0dfd6-9a9b-4b3c-bf17    8.09
# 4  UUID_LOD2_097606-3624f8f5-ebd2-4809-8e81    3.35
#
#                                             geometry
# 0  MULTIPOLYGON Z (((-7168.712 332406.014 128.52,...
# 1  POLYGON Z ((-7227.026 332368.198 132.7, -7229....
# 2  POLYGON Z ((-7262.335 332346.41 128.04, -7263....
# 3  POLYGON Z ((-7288.838 332349.024 133.64, -7291...
# 4  POLYGON Z ((-7116.148 332415.649 126.26, -7118...
#                                   object_id  height
# 0  UUID_LOD2_085505-1e80527f-dddd-47b8-9690    9.33  \
# 1  UUID_LOD2_090674-19cee4ba-1998-46d5-ae04    8.08
# 2  UUID_LOD2_090729-69f17e6d-7738-4167-8436    4.79
# 3  UUID_LOD2_109875-6b26f85c-931f-42b7-9323    7.74
# 4  UUID_LOD2_110070-baac8c94-d40c-4679-9fb5    3.50
#
#                                             geometry
# 0  POLYGON Z ((-7377.885 333307.912 108.311, -737...
# 1  POLYGON Z ((-7496.83 333215.51 99.1, -7496.418...
# 2  POLYGON Z ((-7283.281 333161.318 104.39, -7284...
# 3  POLYGON Z ((-7443.24 333272.93 102.876, -7438....
# 4  POLYGON Z ((-7339 333313.99 98.75, -7329.82 33...
#                                   object_id  height
# 0  UUID_LOD2_A01511-560796e9-4f7d-4c0f-b622    8.39  \
#
#                                             geometry
# 0  POLYGON Z ((-7303.75 333947.29 115.073, -7298....
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 085068.gml
#                                   object_id  height
# 0  UUID_LOD2_163064-b895893c-e927-465d-b6c9    4.42  \
# 1  UUID_LOD2_165056-4283fb43-083a-46a1-9065    6.67
# 2  UUID_LOD2_187034-3a277081-64ff-4f4d-9173    5.91
# 3  UUID_LOD2_187035-668ede82-9993-4546-9358    5.35
# 4  UUID_LOD2_187036-792873f4-e4b0-4cdd-937b    3.50
#
#                                             geometry
# 0  POLYGON Z ((-7027.815 339918.744 77.72, -7030....
# 1  POLYGON Z ((-7025.49 339984.47 82.09, -7028.67...
# 2  POLYGON Z ((-7006.449 339974.32 79.46, -7010.1...
# 3  POLYGON Z ((-7042.527 339992.333 82.11, -7044....
# 4  POLYGON Z ((-7056.86 339984.322 81.1, -7058.66...
#                                   object_id  height
# 0  UUID_LOD2_037341-1e30d403-3fa3-42de-9f26    4.17  \
# 1  UUID_LOD2_037341-9845f7f5-d46f-49bd-9239    8.16
# 2  UUID_LOD2_037342-8eb7c419-61b3-426c-8892    4.08
# 3  UUID_LOD2_037343-399001af-1d67-4991-bded    6.04
# 4  UUID_LOD2_152748-5c7c2e57-7181-473e-9f72   13.50
#
#                                             geometry
# 0  POLYGON Z ((-7431.905 340472.57 67.93, -7432.0...
# 1  POLYGON Z ((-7434.718 340489.063 71.674, -7435...
# 2  POLYGON Z ((-7292.911 340362.835 68.4, -7294.6...
# 3  POLYGON Z ((-7264.303 340183.837 75.639, -7264...
# 4  POLYGON Z ((-7091.29 340061.78 81.182, -7090.0...
#                                   object_id  height
# 0  UUID_LOD2_042002-f05b35aa-8997-47ad-a34f    9.19  \
# 1  UUID_LOD2_042041-733a3026-088f-424c-91e2   10.32
# 2  UUID_LOD2_042045-7ed31b8d-e80d-44c5-8af2   10.93
# 3  UUID_LOD2_042056-53ac8b6f-eae8-410a-976f    5.96
# 4  UUID_LOD2_042085-f05cfa2a-2397-49cb-a0f1   11.34
#
#                                             geometry
# 0  POLYGON Z ((-7032.56 340883.67 100.338, -7030....
# 1  POLYGON Z ((-7093.683 340792.346 105.54, -7095...
# 2  POLYGON Z ((-7176.03 340884.58 81.147, -7179.9...
# 3  POLYGON Z ((-7069.702 340933.862 92.32, -7068....
# 4  POLYGON Z ((-7017.125 340950.119 99.32, -7021....
#                                   object_id  height
# 0  UUID_LOD2_041974-36cfbf0c-8979-4d1a-8fea    5.09  \
# 1  UUID_LOD2_041974-e294634f-41cf-4540-8a55   10.93
# 2  UUID_LOD2_179534-e65244a6-f8ca-4894-90a1    3.76
# 3  UUID_LOD2_174514-719e2657-d4ee-4a16-9f04    9.38
# 4  UUID_LOD2_041979-4c7f3e16-72ab-466a-b60c    6.25
#
#                                             geometry
# 0  POLYGON Z ((-7054.125 341102.501 85.839, -7055...
# 1  POLYGON Z ((-7046.42 341107.54 91.62, -7050.28...
# 2  POLYGON Z ((-7376.612 341020.945 72.641, -7378...
# 3  POLYGON Z ((-7195.203 341236.319 97.791, -7197...
# 4  POLYGON Z ((-7009.651 341224.731 97.63, -7013....
#                                   object_id  height
# 0  UUID_LOD2_042077-37b20bc1-4154-4bdd-a9a2    7.66  \
# 1  UUID_LOD2_042425-b2d7c639-8e89-49c5-8810    9.65
# 2  UUID_LOD2_180421-65cc215f-6c3a-40cb-b97f    5.49
# 3  UUID_LOD2_042427-440c2986-d7f4-46a1-8857    9.36
# 4  UUID_LOD2_180424-974d7ea5-954c-45ea-8e5f    3.72
#
#                                             geometry
# 0  POLYGON Z ((-7384.5 341500.83 87.81, -7381.33 ...
# 1  POLYGON Z ((-7465.71 341548.3 87.541, -7464.91...
# 2  POLYGON Z ((-7355.48 341893.281 93.03, -7356.1...
# 3  POLYGON Z ((-7406.628 341639.452 93.84, -7406....
# 4  POLYGON Z ((-7294.8 341908.81 92.39, -7296.26 ...
#                                   object_id  height
# 0  UUID_LOD2_042653-0bd46ba5-1e5c-47b9-b872    6.33  \
# 1  UUID_LOD2_042654-5bcb3a61-79fe-4c80-92e3    7.84
# 2  UUID_LOD2_180361-dbf5fe34-9642-484f-9090    5.92
# 3  UUID_LOD2_180363-0331ab65-9000-4492-b8d2    5.60
# 4  UUID_LOD2_180364-5f84dfcf-65a9-4fa6-b22a    4.27
#
#                                             geometry
# 0  POLYGON Z ((-7000.81 342013.3 117.525, -7007.5...
# 1  POLYGON Z ((-7047.788 342012.174 116.35, -7048...
# 2  POLYGON Z ((-7356.229 342022.996 99.496, -7356...
# 3  POLYGON Z ((-7377.467 342043.312 101.52, -7379...
# 4  POLYGON Z ((-7395.495 342055.981 95.9, -7394.0...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 086064.gml
#                                   object_id  height
# 0  UUID_LOD2_085394-05d58609-4cbd-4351-92a4    9.57  \
# 1  UUID_LOD2_085556-4673199e-d3a3-4f57-a2a6   13.11
#
#                                             geometry
# 0  POLYGON Z ((-6702.632 332588.217 122.573, -670...
# 1  POLYGON Z ((-6115.954 332924.961 88.54, -6115....
#                                   object_id  height
# 0  UUID_LOD2_085493-4e427149-038f-449e-a682    8.06  \
# 1  UUID_LOD2_085494-d3aad9da-733b-4acc-8946    9.73
# 2  UUID_LOD2_085498-9c7b9169-5d84-4c8b-85cd    3.02
# 3  UUID_LOD2_085500-2a735aa3-bac5-4f92-a5ab   10.85
# 4  UUID_LOD2_085533-fa2c3b48-8188-4cb2-b8d2    5.83
#
#                                             geometry
# 0  POLYGON Z ((-6595.227 333245.708 104.622, -659...
# 1  POLYGON Z ((-6675.73 333268.36 113.465, -6675....
# 2  POLYGON Z ((-6813.27 333283.67 98.188, -6812.6...
# 3  POLYGON Z ((-6898.93 333294.88 96.17, -6898.79...
# 4  POLYGON Z ((-6867.79 333386.98 96.52, -6866.56...
#                                   object_id  height
# 0  UUID_LOD2_085522-e6b1f248-f627-4748-ba78   11.53  \
# 1  UUID_LOD2_085541-0c43a48b-3332-458c-9986   17.89
# 2  UUID_LOD2_140212-cf198fff-bd70-4b50-92d1    6.92
#
#                                             geometry
# 0  POLYGON Z ((-6818.999 333534.574 111.73, -6819...
# 1  POLYGON Z ((-6658.682 333533.211 123.35, -6658...
# 2  POLYGON Z ((-6716.889 333618.175 148.27, -6719...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 086069.gml
#                                   object_id  height
# 0  UUID_LOD2_A02630-51d2b964-12f9-4871-a4a0    5.27  \
#
#                                             geometry
# 0  POLYGON Z ((-6844.25 337915.271 279, -6844.88 ...
#                                   object_id  height
# 0  UUID_LOD2_A02629-fb9f1d2a-1b1b-4563-bacb    4.63  \
#
#                                             geometry
# 0  POLYGON Z ((-6526 338106.325 290.661, -6526.09...
#                                   object_id  height
# 0  UUID_LOD2_187029-0503142e-4cb7-4f22-a5ae    3.85  \
# 1  UUID_LOD2_187030-e5fe24b0-7f0f-4309-8015    5.25
# 2  UUID_LOD2_187031-07ee9022-821a-42f1-8b9f    5.58
# 3  UUID_LOD2_187032-3fd62e6c-1da2-4335-bdf4    3.40
# 4  UUID_LOD2_187033-5a2cda9b-0a3a-42c8-9039    4.54
#
#                                             geometry
# 0  POLYGON Z ((-6971.123 339991.709 74.43, -6971....
# 1  POLYGON Z ((-6963.203 339988.009 75.19, -6966....
# 2  POLYGON Z ((-6954.129 339983.899 75.07, -6958....
# 3  POLYGON Z ((-6979.54 339967.53 73.388, -6977.4...
# 4  POLYGON Z ((-6993.71 339977.14 75.684, -6993.6...
#                                   object_id  height
# 0  UUID_LOD2_041247-58485b40-2870-4bfb-9f8b    7.69  \
# 1  UUID_LOD2_116710-4ec03f63-5e55-428b-94d7    5.69
# 2  UUID_LOD2_164739-ef111717-6693-4cf1-98bf    5.30
# 3  UUID_LOD2_179285-634a4a18-4de0-4b6d-ae2e    3.81
# 4  UUID_LOD2_179289-628444e6-9955-4692-8248    2.46
#
#                                             geometry
# 0  POLYGON Z ((-6699.35 340505.91 61.092, -6698.5...
# 1  POLYGON Z ((-6987.768 339998.915 77.812, -6990...
# 2  MULTIPOLYGON Z (((-6905.159 340167.221 71.05, ...
# 3  POLYGON Z ((-6579.6 340468.31 64.326, -6576.90...
# 4  MULTIPOLYGON Z (((-6619.8 340473.881 64.28, -6...
#                                   object_id  height
# 0  UUID_LOD2_124876-45a4bf93-0a80-4f1f-a748    8.54  \
# 1  UUID_LOD2_041249-c8a95a73-63d9-431a-bd52    6.45
# 2  UUID_LOD2_124878-98d31dd1-348b-4921-a886    7.63
# 3  UUID_LOD2_041249-fb4f8d0e-1026-4009-b7c0    7.85
# 4  UUID_LOD2_041803-e7bdd94c-e9dd-4471-b064   13.81
#
#                                             geometry
# 0  POLYGON Z ((-6925.053 340747.456 109.58, -6923...
# 1  POLYGON Z ((-6838.55 340534.66 61.62, -6836.46...
# 2  POLYGON Z ((-6948.43 340763.18 104.82, -6947.8...
# 3  MULTIPOLYGON Z (((-6780.136 340556.667 68.544,...
# 4  POLYGON Z ((-6611.61 340686.19 85.796, -6611.7...
#                                   object_id  height
# 0  UUID_LOD2_128821-25eecccb-7f98-48f6-9e63   10.28  \
# 1  UUID_LOD2_128819-1d943d4e-9a52-4921-8616    4.89
# 2  UUID_LOD2_041791-0d54447e-5edc-4779-993c    5.41
# 3  UUID_LOD2_041791-fbddf694-2876-4207-96a7    8.27
# 4  UUID_LOD2_041786-aa925458-1d57-4267-a586    5.81
#
#                                             geometry
# 0  POLYGON Z ((-6792.345 341483.1 128.118, -6794....
# 1  POLYGON Z ((-6809.7 341471.35 115.63, -6808.92...
# 2  POLYGON Z ((-6548.535 341122.897 125.7, -6548....
# 3  POLYGON Z ((-6570.038 341093.886 119.915, -657...
# 4  POLYGON Z ((-6529.01 341074.82 112.18, -6527.7...
#                                   object_id  height
# 0  UUID_LOD2_042441-bc68ef3e-0027-41af-a744    8.74  \
# 1  UUID_LOD2_042444-cfbf69d3-ea03-4bb6-a239   10.23
# 2  UUID_LOD2_042449-2dd9261f-1eab-4c29-8ad0   10.21
# 3  UUID_LOD2_042450-806e7064-9967-411d-8034    9.52
# 4  UUID_LOD2_042451-7c731f77-d5ed-4f54-b2e5   10.98
#
#                                             geometry
# 0  POLYGON Z ((-6904.227 341595.214 122.044, -690...
# 1  POLYGON Z ((-6810.75 341757.399 128.687, -6813...
# 2  POLYGON Z ((-6769.208 341777.06 121.228, -6769...
# 3  POLYGON Z ((-6785.713 341734.508 118.35, -6786...
# 4  POLYGON Z ((-6755.531 341775.26 132.2, -6756.7...
#                                   object_id  height
# 0  UUID_LOD2_042519-ec593aa3-3854-4bc9-a743   10.48  \
# 1  UUID_LOD2_042687-f1d636ff-2cc4-456e-bed9   11.55
# 2  UUID_LOD2_042702-2e926724-25a8-438f-a6b6    8.57
# 3  UUID_LOD2_042702-83ddb45b-02e3-4e5c-8b5e    3.46
# 4  UUID_LOD2_042704-c5399ed9-2cc1-4e10-9b6d   10.70
#
#                                             geometry
# 0  POLYGON Z ((-6896.696 342016.147 123.17, -6897...
# 1  POLYGON Z ((-6512.323 342297.057 140.329, -651...
# 2  POLYGON Z ((-6627.49 342329.605 143.35, -6626....
# 3  POLYGON Z ((-6636.296 342321.415 141.25, -6638...
# 4  POLYGON Z ((-6645.01 342328.045 148, -6648.98 ...
#                                   object_id  height
# 0  UUID_LOD2_042694-8e151532-d383-4907-95eb    8.58  \
# 1  UUID_LOD2_042915-f106846c-f028-416c-b771    4.72
# 2  UUID_LOD2_042917-892c890e-1ef6-42bf-a1e7    9.90
# 3  UUID_LOD2_042919-1934364a-4ceb-4954-90e0    3.32
# 4  UUID_LOD2_042920-3ac74fa9-ecdf-45da-b53c    3.76
#
#                                             geometry
# 0  POLYGON Z ((-6548.987 342853.875 134.449, -654...
# 1  POLYGON Z ((-6674.999 342557.345 142.356, -667...
# 2  POLYGON Z ((-6667.917 342568.467 134.104, -666...
# 3  POLYGON Z ((-6693.82 342643.087 134.743, -6699...
# 4  POLYGON Z ((-6621.495 342607.455 133.14, -6624...
#                                   object_id  height
# 0  UUID_LOD2_042285-2ebbc4bb-de7a-46de-bb74    4.60  \
# 1  UUID_LOD2_042285-70fdfdf6-c48d-4d4d-be06    6.74
# 2  UUID_LOD2_042760-aec1e393-6188-4c36-b27d    9.37
# 3  UUID_LOD2_097675-3449ee8a-1158-4c41-9335    7.85
#
#                                             geometry
# 0  MULTIPOLYGON Z (((-6551.31 343164.16 121.13, -...
# 1  POLYGON Z ((-6552.323 343173.025 128.318, -655...
# 2  POLYGON Z ((-6540.512 342999.492 126.45, -6540...
# 3  POLYGON Z ((-6535.311 342988.695 126.164, -653...
#                                   object_id  height
# 0  UUID_LOD2_130460-1c956ebf-3b82-45e6-80e2    8.59  \
# 1  UUID_LOD2_180337-4847d62b-0fd0-4535-b0a4    4.93
# 2  UUID_LOD2_180338-262ebb58-6073-462f-a9dd    5.87
# 3  UUID_LOD2_180339-ecb34f4c-eca9-4dab-acc4    7.06
# 4  UUID_LOD2_180344-86b5de98-8c92-4bdd-a825    8.80
#
#                                             geometry
# 0  POLYGON Z ((-6903.32 344486.23 193.959, -6904....
# 1  POLYGON Z ((-6771.03 344406.04 175.865, -6772....
# 2  POLYGON Z ((-6783.222 344417.289 179.328, -678...
# 3  POLYGON Z ((-6804.423 344417.289 174.96, -6805...
# 4  POLYGON Z ((-6838.24 344458.62 180.2, -6836.65...
#                                   object_id  height
# 0  UUID_LOD2_042954-38bfe9df-64f7-40ae-aa50    7.75  \
# 1  UUID_LOD2_180352-83d635e8-d248-4545-849a    6.63
# 2  UUID_LOD2_226565-53f1c82e-bea5-4afe-8304    3.28
#
#                                             geometry
# 0  POLYGON Z ((-6893.07 344502.52 183.18, -6889.7...
# 1  POLYGON Z ((-6828.196 344518.857 185.4, -6829....
# 2  POLYGON Z ((-6896.99 344594.85 184.459, -6894....
#                                   object_id  height
# 0  UUID_LOD2_043566-2b3fb536-cc16-42b6-84ed   13.06  \
#
#                                             geometry
# 0  POLYGON Z ((-6978.96 345643.886 351.939, -6984...
#                                   object_id  height
# 0  UUID_LOD2_085390-ab60fbdd-c36f-4b9b-b822    6.69  \
# 1  UUID_LOD2_085390-d579467e-f4cb-45d9-a457    5.86
# 2  UUID_LOD2_085408-61f62a3c-c318-48be-8843    4.33
# 3  UUID_LOD2_085412-b785df30-6680-4440-89d9    2.70
# 4  UUID_LOD2_085412-ec5c01b9-9262-4134-a22e    9.91
#
#                                             geometry
# 0  POLYGON Z ((-6446.72 332607.922 119.04, -6447....
# 1  MULTIPOLYGON Z (((-6429.145 332617.954 115.014...
# 2  POLYGON Z ((-6150.125 332551.795 112.86, -6150...
# 3  POLYGON Z ((-6244.527 332570.653 111.32, -6246...
# 4  POLYGON Z ((-6238.24 332580.91 114.497, -6240....
#                                   object_id  height
# 0  UUID_LOD2_076259-04af106a-26b9-46f2-8625   10.39  \
# 1  UUID_LOD2_085482-1e2c27d6-3f38-4fc0-91f5    7.58
# 2  UUID_LOD2_085486-41a54415-6764-41b4-99f2   22.59
# 3  UUID_LOD2_085490-16b1a1fd-6b5e-4dda-b1a6    3.17
# 4  UUID_LOD2_085490-885fdb1b-91a0-4161-8cee    3.67
#
#                                             geometry
# 0  POLYGON Z ((-6070.57 333336.86 132.366, -6072....
# 1  POLYGON Z ((-6142.78 333183.8 89.82, -6137.2 3...
# 2  POLYGON Z ((-6197.8 333119.602 109.988, -6196....
# 3  POLYGON Z ((-6262.91 333239.99 94.044, -6262.1...
# 4  POLYGON Z ((-6284.81 333261.935 98.7, -6285 33...
#                                   object_id  height
# 0  UUID_LOD2_A01441-7530969e-98e0-42c4-88ef    3.55  \
#
#                                             geometry
# 0  POLYGON Z ((-6013.253 335140.513 177.85, -6012...
#                                   object_id  height
# 0  UUID_LOD2_034774-23173ecb-7ee2-4615-9d3e    4.98  \
# 1  UUID_LOD2_034774-7e765bb2-f3e1-4c94-be9e    3.85
# 2  UUID_LOD2_034774-9c00dcb0-25e7-4398-99ed    3.84
#
#                                             geometry
# 0  POLYGON Z ((-6268.281 336373.81 122.16, -6269....
# 1  POLYGON Z ((-6381.501 336312.241 124.14, -6383...
# 2  POLYGON Z ((-6354.91 336321.71 122.068, -6352....
#                                   object_id  height
# 0  UUID_LOD2_034771-07b1f2b8-2df1-4a0c-92e3   12.96  \
# 1  UUID_LOD2_034771-2bd8c7a8-7550-472d-8242    6.18
# 2  UUID_LOD2_034771-2e7c6fd5-8d72-48d6-92d4   10.58
# 3  UUID_LOD2_034771-4c1052ad-6a90-4880-8185    9.17
# 4  UUID_LOD2_034771-64831160-a16a-4043-939d   13.89
#
#                                             geometry
# 0  POLYGON Z ((-6510.53 337102.37 155.244, -6531....
# 1  POLYGON Z ((-6679.34 336804.29 142.66, -6679.3...
# 2  POLYGON Z ((-6155.79 336911.51 134.274, -6152....
# 3  POLYGON Z ((-6572.01 337150.62 150.21, -6571.1...
# 4  POLYGON Z ((-6504.29 337000 150.782, -6504.17 ...
#                                   object_id  height
# 0  UUID_LOD2_187119-ca8a83bc-4fb1-4d00-86b7    3.44  \
# 1  UUID_LOD2_187120-6139147a-d214-4002-99c0    3.11
#
#                                             geometry
# 0  POLYGON Z ((-6012.053 338914.379 222.12, -6013...
# 1  POLYGON Z ((-6020.01 338929.132 228.08, -6020....
#                                   object_id  height
# 0  UUID_LOD2_041258-021d34e6-372f-401e-a01c   11.43  \
# 1  UUID_LOD2_212963-1ee147e1-a1c3-479f-acce   15.03
# 2  UUID_LOD2_214480-a3f5d312-3bb4-4652-bc83   15.44
# 3  UUID_LOD2_A01174-a9a5fda7-85ba-4e78-9c85    5.17
# 4  UUID_LOD2_A01174-d17e33db-091b-45e1-a8de    2.92
#
#                                             geometry
# 0  POLYGON Z ((-6419.41 340480.73 64.565, -6413.7...
# 1  POLYGON Z ((-6472.06 340478.75 61.154, -6471.5...
# 2  POLYGON Z ((-6476.09 340448.74 59.804, -6475.9...
# 3  POLYGON Z ((-5970.079 340333.705 60.9, -5972.4...
# 4  POLYGON Z ((-5981.802 340340.338 58.7, -5985.0...
#                                   object_id  height
# 0  UUID_LOD2_041243-60a4705d-0148-4768-8123   15.43  \
# 1  UUID_LOD2_041455-401bf1ff-4be0-4d29-8480    7.50
# 2  UUID_LOD2_041459-da09fad6-5a6c-4cf6-b6d4   11.23
# 3  UUID_LOD2_041466-bfc81be8-0ec1-4889-aaeb   12.74
# 4  UUID_LOD2_041470-a7eb54c8-8f07-445a-a09f    3.00
#
#                                             geometry
# 0  POLYGON Z ((-6450.886 340543.197 66.582, -6450...
# 1  POLYGON Z ((-6139.92 340917.12 98.018, -6139.6...
# 2  POLYGON Z ((-6176.03 340857.7 95.241, -6175.54...
# 3  POLYGON Z ((-6211.154 340862.15 90.39, -6211.1...
# 4  POLYGON Z ((-6245.512 340894.015 93.7, -6248.7...
#                                   object_id  height
# 0  UUID_LOD2_103467-4ae1b48b-59fa-4668-a7fc    9.05  \
# 1  UUID_LOD2_041419-d9cfba91-65e7-49d2-a010   10.88
# 2  UUID_LOD2_041422-bb95716e-7bec-4506-9f3d   10.03
# 3  UUID_LOD2_041423-80b7fbd0-cddf-4568-a8cd   15.69
# 4  UUID_LOD2_041435-079e4d52-4762-45ec-ba4e   11.37
#
#                                             geometry
# 0  POLYGON Z ((-6090.8 341186.57 139.511, -6086.9...
# 1  POLYGON Z ((-6143.43 341014.62 107.722, -6143....
# 2  POLYGON Z ((-6169.4 341014 115.472, -6169.397 ...
# 3  POLYGON Z ((-6185.028 341010.423 118.764, -618...
# 4  POLYGON Z ((-6318.12 341006.97 107.68, -6317.3...
#                                   object_id  height
# 0  UUID_LOD2_042211-89cb6234-8206-4c0d-b2ad   10.83  \
# 1  UUID_LOD2_042216-a4a7a2d1-2497-41fa-83c5   10.05
# 2  UUID_LOD2_A35799-f48a1095-2682-4473-9320    5.28
# 3  UUID_LOD2_A35797-b44c8160-cc44-4a81-a9b6    5.56
# 4  UUID_LOD2_A35801-08b4f192-56da-4180-ab45    6.64
#
#                                             geometry
# 0  POLYGON Z ((-6028.816 341558.336 90.736, -6031...
# 1  POLYGON Z ((-6171.444 341840.078 99.341, -6174...
# 2  POLYGON Z ((-6330.744 341528.96 146.047, -6333...
# 3  POLYGON Z ((-6350.008 341526.07 149.097, -6352...
# 4  POLYGON Z ((-6348.885 341513.09 152.354, -6351...
#                                   object_id  height
# 0  UUID_LOD2_042152-043f91db-d624-4c1c-8b42    5.32  \
# 1  UUID_LOD2_042152-0f992b81-03c1-49e9-a3cc    4.72
# 2  UUID_LOD2_042152-132a9749-4a1f-4fbc-af3f    3.77
# 3  UUID_LOD2_042152-182d1357-a67f-4dd5-bbbb    5.54
# 4  UUID_LOD2_042152-202392f1-67b0-4d3b-8dd2    4.27
#
#                                             geometry
# 0  POLYGON Z ((-6139.05 342588.39 129.519, -6135....
# 1  POLYGON Z ((-6080.21 342436.74 108.281, -6079....
# 2  POLYGON Z ((-6096.158 342413.127 102.464, -609...
# 3  POLYGON Z ((-6120.615 342602.504 133.05, -6116...
# 4  POLYGON Z ((-6126.7 342512.35 111.872, -6122.8...
#                                   object_id  height
# 0  UUID_LOD2_042267-6c3c5718-9a2a-4545-aaac   12.55  \
# 1  UUID_LOD2_042268-b9e61672-b2b2-4203-b81b    8.45
# 2  UUID_LOD2_042270-a18e156c-4334-4575-925c    4.58
# 3  UUID_LOD2_042270-eac19e63-eacc-41c7-8537    3.00
# 4  UUID_LOD2_042271-3bb1bb01-d08c-42b0-8c32   10.04
#
#                                             geometry
# 0  POLYGON Z ((-6264.69 342625.99 113.369, -6262....
# 1  POLYGON Z ((-6291.97 342612.08 106.048, -6286....
# 2  POLYGON Z ((-6302.025 342672.711 110.45, -6302...
# 3  POLYGON Z ((-6288.573 342709.56 111.152, -6289...
# 4  MULTIPOLYGON Z (((-6311.34 342753.861 108.71, ...
#                                   object_id  height
# 0  UUID_LOD2_002207-638ff976-d534-451d-8a3f   12.23  \
# 1  UUID_LOD2_002485-9be0079d-b7f2-424d-969a   12.26
# 2  UUID_LOD2_085395-6450500c-cc03-4c5d-80f9    8.88
#
#                                             geometry
# 0  POLYGON Z ((-5615.105 332407.901 104.41, -5615...
# 1  POLYGON Z ((-5572.08 332417.11 103.63, -5573.5...
# 2  POLYGON Z ((-5658.78 332437.94 104.392, -5654....
#                                   object_id  height
# 0  UUID_LOD2_085376-372addf3-a9bb-42da-85d2    9.15  \
# 1  UUID_LOD2_085434-71749a8c-79d4-4fdf-b997    4.47
# 2  UUID_LOD2_085458-a5f75b6d-3e66-46d6-8eaa   10.15
# 3  UUID_LOD2_085467-722d6116-04a1-4393-8785    3.86
# 4  UUID_LOD2_085595-da48f78e-8684-4889-a8bb    3.60
#
#                                             geometry
# 0  POLYGON Z ((-5510 332677.682 96.5, -5516.18 33...
# 1  POLYGON Z ((-5673.729 332775.9 96.85, -5675.23...
# 2  MULTIPOLYGON Z (((-5583.81 332972.471 86.78, -...
# 3  POLYGON Z ((-5498.025 332967.17 89.7, -5498.23...
# 4  POLYGON Z ((-5812.293 332900.873 91.148, -5815...
#                                   object_id  height
# 0  UUID_LOD2_085445-91a269d2-7650-4886-ad74    5.76  \
# 1  UUID_LOD2_085447-b2fd3520-ac30-4b16-afb0   10.22
# 2  UUID_LOD2_085578-f881dada-e06f-43dd-8eb1    6.98
# 3  UUID_LOD2_085601-ce277f69-c658-44fd-9182    8.62
# 4  UUID_LOD2_085605-08e1f399-ecc6-4623-a9ff   14.55
#
# ...
# 3  POLYGON Z ((5190.777 345127.653 11.78, 5190.79...
# 4  POLYGON Z ((5381.06 345050.79 6.024, 5382.23 3...
#                                   object_id  height
# 0  UUID_LOD2_065511-37a3f0eb-8389-4869-8b1d    2.59  \
# 1  UUID_LOD2_065529-980d599a-741d-42f4-b890   16.20
# 2  UUID_LOD2_071434-2b8bc2a6-5881-498c-aa8e    6.35
# 3  UUID_LOD2_092670-57216a3b-895b-4e8d-ab19   10.02
# 4  UUID_LOD2_097830-a6bd9af3-ad28-4b2d-8ab7    4.48
#
#                                             geometry
# 0  POLYGON Z ((5277.77 345628.39 1.195, 5277.975 ...
# 1  POLYGON Z ((5206.01 345984.034 16.922, 5206.84...
# 2  POLYGON Z ((5016.29 345513.94 3.82, 5019.843 3...
# 3  POLYGON Z ((5292.411 345835.643 14.51, 5287.99...
# 4  POLYGON Z ((5064.488 345594.675 5.923, 5064.29...
#                                   object_id  height
# 0  UUID_LOD2_065475-3404a242-9d46-4c17-a10e   11.02  \
# 1  UUID_LOD2_065577-3e35bae0-52f7-4329-b48b    3.82
# 2  UUID_LOD2_065594-102b38a5-f973-4b20-95f2   16.20
# 3  UUID_LOD2_065605-ada3acb8-eba2-45d7-91fa   16.57
# 4  UUID_LOD2_065607-8158f7fb-8a66-4f0b-9ba1   12.40
#
#                                             geometry
# 0  POLYGON Z ((5486.676 346275.424 16.324, 5483.1...
# 1  POLYGON Z ((5219.98 346251.39 7.92, 5220.707 3...
# 2  POLYGON Z ((5459.438 346299.374 17.873, 5459.4...
# 3  POLYGON Z ((5252.86 346395.75 5.57, 5258.77 34...
# 4  POLYGON Z ((5284.713 346375.091 13.324, 5288.3...
#                                   object_id  height
# 0  UUID_LOD2_064770-809173d7-2f25-45fa-8199   17.21  \
# 1  UUID_LOD2_064771-75d352fe-ebbd-44d1-af1a   17.29
# 2  UUID_LOD2_064774-fb905ebb-d71d-45f7-bca8   15.69
# 3  UUID_LOD2_064779-35473d80-6c92-42ca-866d   15.90
# 4  UUID_LOD2_064783-8c497a09-69a8-4a3e-9ead   16.05
#
#                                             geometry
# 0  POLYGON Z ((4988.205 346858.883 6.27, 4992.425...
# 1  POLYGON Z ((5009.929 346850.321 23.34, 5013.08...
# 2  POLYGON Z ((5095.524 346792.579 6.14, 5095.428...
# 3  POLYGON Z ((5127.54 346814.94 18.371, 5122.591...
# 4  POLYGON Z ((5145.061 346833.389 18.337, 5144.2...
#                                   object_id  height
# 0  UUID_LOD2_064673-34873aeb-e41a-4811-af4c   15.04  \
# 1  UUID_LOD2_064718-74f45d7f-dd44-427e-bce1   20.85
# 2  UUID_LOD2_064789-08089cb1-daa4-493c-846d   21.05
# 3  UUID_LOD2_064790-2a56a7c2-ffb8-4e3e-a4a1    0.92
# 4  UUID_LOD2_071610-30bdae7b-5773-4e7a-bcd4   11.63
#
#                                             geometry
# 0  POLYGON Z ((5273.574 347185.048 5.629, 5273.69...
# 1  POLYGON Z ((5426.42 347150.63 21.376, 5427.3 3...
# 2  POLYGON Z ((5161.44 347268.49 24.31, 5161.57 3...
# 3  POLYGON Z ((5352.241 347300.224 7.93, 5350 347...
# 4  POLYGON Z ((5034.51 347212.87 14.299, 5035.064...
#                                   object_id  height
# 0  UUID_LOD2_118111-032a1e1c-2c6e-4212-8152   15.09  \
# 1  UUID_LOD2_501854-2e7ee8ab-f53d-4dae-a006    3.13
# 2  UUID_LOD2_501857-ac69989f-78bf-43c4-8e8b    3.27
# 3  UUID_LOD2_501858-d701f2e5-3483-4e6a-a2bd    5.44
# 4  UUID_LOD2_501859-4be51fe8-ec62-4d38-bb90    2.85
#
#                                             geometry
# 0  POLYGON Z ((5314.194 348026.529 20.32, 5317.24...
# 1  POLYGON Z ((5315.717 347901.348 7.45, 5314.75 ...
# 2  POLYGON Z ((5291.38 347861.79 4.41, 5292.816 3...
# 3  POLYGON Z ((5285.24 347843.84 8.168, 5285.58 3...
# 4  POLYGON Z ((5286.26 347826.4 6.325, 5284.78 34...
#                                   object_id  height
# 0  UUID_LOD2_067825-9fa8d1a3-ee83-412e-b82c    9.02  \
# 1  UUID_LOD2_128355-8aacaefa-b9ec-4c2b-aec0    6.84
# 2  UUID_LOD2_134258-ee0d85fe-ea01-4ef9-8a6b   12.29
# 3  UUID_LOD2_148998-dd0862fe-92d2-4608-b58b    8.51
# 4  UUID_LOD2_A03901-f0c17532-a0b3-408e-98b4    2.62
#
#                                             geometry
# 0  POLYGON Z ((5029.95 348489.28 5.79, 5040.21 34...
# 1  POLYGON Z ((5407.74 348204.72 13.181, 5420.347...
# 2  POLYGON Z ((5241.77 348130.75 6.33, 5241.869 3...
# 3  POLYGON Z ((5265.55 348193.479 6.149, 5265.75 ...
# 4  POLYGON Z ((5056.888 348042.454 7.568, 5058.54...
#                                   object_id  height
# 0  UUID_LOD2_067795-d2ac0052-ac40-4a04-a385   15.89  \
# 1  UUID_LOD2_067853-cae1b4f9-3e16-4b14-8279   14.17
# 2  UUID_LOD2_067856-05f3e425-34e6-4837-8535   14.39
# 3  UUID_LOD2_067857-39f4a8a0-959e-4d86-b626   14.38
# 4  UUID_LOD2_067858-3344f41a-4497-4f98-86b3   14.45
#
#                                             geometry
# 0  POLYGON Z ((5486.95 348649.9 16.847, 5493.146 ...
# 1  POLYGON Z ((5081.607 348933.81 6.471, 5081.839...
# 2  POLYGON Z ((5142.15 348912.95 17.095, 5137.727...
# 3  POLYGON Z ((5153.88 348908.69 16.655, 5153.717...
# 4  POLYGON Z ((5166.49 348905.11 6.121, 5166.522 ...
#                                   object_id  height
# 0  UUID_LOD2_067870-4e795426-5229-47ee-9d30   10.41  \
# 1  UUID_LOD2_067891-b71f8422-2b7e-4058-975e    2.22
# 2  UUID_LOD2_067891-e8e189ab-8518-4f02-adbd    2.65
# 3  UUID_LOD2_067897-cbe53e6c-6f01-4c38-b868    9.58
# 4  UUID_LOD2_067952-9f40b4de-de83-46fc-84ec    3.82
#
#                                             geometry
# 0  POLYGON Z ((5321.21 349476.412 17.346, 5316.28...
# 1  POLYGON Z ((5143.01 349022.53 7.774, 5137.82 3...
# 2  POLYGON Z ((5147.534 349024.061 9.481, 5146.77...
# 3  POLYGON Z ((5226.214 349041.308 14.42, 5225.12...
# 4  MULTIPOLYGON Z (((5178.44 349467.41 6.73, 5181...
#                                   object_id  height
# 0  UUID_LOD2_067885-65ad0a6c-5b7a-49be-b0b1   10.42  \
# 1  UUID_LOD2_067924-0894ab6b-2db5-413e-b5f0    4.26
# 2  UUID_LOD2_067925-55bfe94b-1880-4471-9b12    3.83
# 3  UUID_LOD2_067935-0ba82c59-88e6-4db5-a6d9    8.38
# 4  UUID_LOD2_067937-d24f3159-19d0-4e39-ae37   10.20
#
#                                             geometry
# 0  POLYGON Z ((5307.77 349934.62 6.269, 5309.72 3...
# 1  POLYGON Z ((5279.65 349680.03 6.404, 5280.419 ...
# 2  POLYGON Z ((5207.67 349737.28 6.749, 5208.825 ...
# 3  POLYGON Z ((5263.7 349803.3 10.876, 5265.685 3...
# 4  POLYGON Z ((5255.43 349825.49 7, 5259.936 3498...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 111062.gml
#                                   object_id  height
# 0  UUID_LOD2_A02091-a451637a-bb9c-4065-8ed9    3.31  \
#
#                                             geometry
# 0  POLYGON Z ((5971.795 331564.29 39.19, 5969.28 ...
#                                   object_id  height
# 0  UUID_LOD2_022248-383bd115-62c3-4b2a-ac57    5.74  \
# 1  UUID_LOD2_022248-b85b86e3-8404-42ff-92e5    3.56
# 2  UUID_LOD2_022251-feef2a54-b8f5-431d-8163    5.70
# 3  UUID_LOD2_022255-c53d12c8-8731-422c-831f    3.37
# 4  UUID_LOD2_022257-1e6cdeb9-e2e9-40e3-bd24    7.38
#
#                                             geometry
# 0  POLYGON Z ((5971.42 332809.53 17.474, 5972.18 ...
# 1  POLYGON Z ((5990.84 332852.87 20.19, 5988.57 3...
# 2  POLYGON Z ((5968.686 332773.115 23.329, 5965.2...
# 3  POLYGON Z ((5889.32 332831.94 19.99, 5889.71 3...
# 4  MULTIPOLYGON Z (((5871.542 332833.523 29.468, ...
#                                   object_id  height
# 0  UUID_LOD2_021947-471200eb-8e15-4070-b227    5.23  \
# 1  UUID_LOD2_021983-f8161bf7-121a-4029-bbfd    8.12
# 2  UUID_LOD2_021987-033c439e-f90e-42eb-86c4    7.40
# 3  UUID_LOD2_021989-29c320fc-fed7-430d-a67d    6.66
# 4  UUID_LOD2_021991-09ca3b0a-d382-4e00-9c2e   10.74
#
#                                             geometry
# 0  MULTIPOLYGON Z (((5515.075 333283.276 25.42, 5...
# 1  POLYGON Z ((5600.96 333186.85 25.709, 5600.993...
# 2  POLYGON Z ((5563.81 333193.22 20.709, 5565.138...
# 3  POLYGON Z ((5550.083 333194.526 27.326, 5547.3...
# 4  POLYGON Z ((5548.34 333257.55 26.949, 5548.79 ...
#                                   object_id  height
# 0  UUID_LOD2_136659-4bc35d52-7dae-45cf-8a6b    2.17  \
# 1  UUID_LOD2_136660-15293187-cd39-45d8-9845    2.56
# 2  UUID_LOD2_A02059-5fe066c1-bf35-42da-972a    2.42
# 3  UUID_LOD2_A02062-9870ad3f-ee05-45f8-9ff2    4.16
#
#                                             geometry
# 0  POLYGON Z ((5563.248 333518.901 34.887, 5563.1...
# 1  POLYGON Z ((5573.55 333520.55 35.025, 5573.28 ...
# 2  POLYGON Z ((5672.965 333892.32 60, 5672.9 3338...
# 3  POLYGON Z ((5831.63 333949.62 67.932, 5832.21 ...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 111068.gml
#                                   object_id  height
# 0  UUID_LOD2_130600-08770c03-170e-4fd2-8095    8.12  \
# 1  UUID_LOD2_130600-67ebaca9-b8da-462f-8b5a    8.36
# 2  UUID_LOD2_130600-6fedd14a-e68d-4e2f-a908    5.57
# 3  UUID_LOD2_130600-84a441b6-8748-4ba2-bead    6.99
# 4  UUID_LOD2_130600-b9e80e2c-6066-43bf-a07e   11.36
#
#                                             geometry
# 0  POLYGON Z ((5541.772 334704.783 98.86, 5542.51...
# 1  POLYGON Z ((5567.74 334826.39 92.927, 5568.709...
# 2  POLYGON Z ((5569.29 334872.92 89.098, 5577.89 ...
# 3  POLYGON Z ((5614.585 334925.21 89.06, 5614.582...
# 4  POLYGON Z ((5628.47 334938.22 94.687, 5627.25 ...
#                                   object_id  height
# 0  UUID_LOD2_019468-8ecd8ffa-5545-4264-8ca2   13.38  \
# 1  UUID_LOD2_019482-40758c80-5323-435c-8de4    8.17
# 2  UUID_LOD2_019522-ca5233f4-698a-4c53-ae6d    3.64
# 3  UUID_LOD2_019526-8bc94e79-3a7d-4f7c-9e34    7.04
# 4  UUID_LOD2_019529-994812cd-2744-4ba1-9cda    9.05
#
#                                             geometry
# 0  POLYGON Z ((5502.114 335183.839 98.048, 5500 3...
# 1  POLYGON Z ((5520.119 335075.264 95.861, 5517.2...
# 2  POLYGON Z ((5520.27 335380.78 77.693, 5522.772...
# 3  POLYGON Z ((5498.56 335262.31 85.437, 5500 335...
# 4  POLYGON Z ((5525.5 335241.82 88.083, 5531.48 3...
#                                   object_id  height
# 0  UUID_LOD2_019488-2e41ab28-2845-4c37-bed5    2.73  \
# 1  UUID_LOD2_019490-e4c58248-e456-444e-b678    9.18
# 2  UUID_LOD2_019496-bb8ee60c-539b-48d6-9445    8.92
# 3  UUID_LOD2_019501-3fc6dc6e-2dbc-41f0-9eb9    9.56
# 4  UUID_LOD2_019504-0fcc530a-e5c7-4f8b-bed1    5.82
#
#                                             geometry
# 0  POLYGON Z ((5639.964 335761.216 66.79, 5639.62...
# 1  POLYGON Z ((5642.982 335699.094 70.006, 5642.9...
# 2  POLYGON Z ((5702.19 335877.03 64.475, 5701.89 ...
# 3  POLYGON Z ((5808.211 335806.599 55.279, 5803.1...
# 4  POLYGON Z ((5879.26 335743.82 54.594, 5875.12 ...
#                                   object_id  height
# 0  UUID_LOD2_019485-86f4193e-96f1-48a2-afb4   11.02  \
# 1  UUID_LOD2_019562-aec77573-2d8c-4ff0-9682    9.23
# 2  UUID_LOD2_019575-d8a06b1d-b25b-4694-98fd    4.10
# 3  UUID_LOD2_019576-69090d1d-53c5-4571-aea8    4.80
# 4  UUID_LOD2_133143-695206b2-150a-4320-bc41    9.85
#
#                                             geometry
# 0  POLYGON Z ((5718.05 336004.25 56.346, 5721.124...
# 1  POLYGON Z ((5747.169 336009.014 55.59, 5742.93...
# 2  POLYGON Z ((5839.573 336046.485 42.04, 5839.63...
# 3  POLYGON Z ((5851.626 336033.671 44.61, 5850.14...
# 4  POLYGON Z ((5731.11 336014.79 56.86, 5726.08 3...
#                                   object_id  height
# 0  UUID_LOD2_025465-8f1d6d52-5f1c-452b-b223   20.97  \
# 1  UUID_LOD2_025466-8d8db8c7-c65a-4cf9-bb89   21.24
# 2  UUID_LOD2_025686-42c6138b-9932-4445-a2e8   23.81
# 3  UUID_LOD2_098568-5cc009ff-9786-4495-9ead    6.30
# 4  UUID_LOD2_098568-c7b6b32a-1f7a-4677-b87a    8.34
#
#                                             geometry
# 0  POLYGON Z ((5915.695 336999.924 35.278, 5915.7...
# 1  POLYGON Z ((5891.115 337000.018 40.43, 5895.37...
# 2  POLYGON Z ((5922.52 336942.91 37.249, 5922.42 ...
# 3  MULTIPOLYGON Z (((5553.43 336981.03 34.16, 555...
# 4  POLYGON Z ((5552.61 336937.66 28.65, 5555.328 ...
#                                   object_id  height
# 0  UUID_LOD2_022416-0c2d84ff-1133-4018-bb29    5.43  \
# 1  UUID_LOD2_022416-d50562b7-7652-4452-aac3    4.51
# 2  UUID_LOD2_022449-e04c3a65-6db0-412b-83cc   20.38
# 3  UUID_LOD2_022711-dc894ed6-8d13-48ad-8f04   17.64
# 4  UUID_LOD2_025336-d9487c21-c575-4cda-8b83   19.48
#
#                                             geometry
# 0  POLYGON Z ((5524.953 337133.484 25.207, 5523.9...
# 1  POLYGON Z ((5509.54 337011.15 31.991, 5511.02 ...
# 2  POLYGON Z ((5775.015 337373.231 40.8, 5771.45 ...
# 3  POLYGON Z ((5917.5 337479.981 30.742, 5920.558...
# 4  MULTIPOLYGON Z (((5626.407 337262.372 37.138, ...
#                                   object_id  height
# 0  UUID_LOD2_022481-1f9ffa78-e9d5-412e-a85d    5.41  \
# 1  UUID_LOD2_022495-d3fccd5e-8675-4dca-a87c   22.53
# 2  UUID_LOD2_022496-d42eabb3-7199-40b7-9aa9   15.79
# 3  UUID_LOD2_022512-44f3867b-64f5-4ba9-8597   20.97
# 4  UUID_LOD2_022717-6cbfc1be-b038-43c1-8646   16.14
#
#                                             geometry
# 0  POLYGON Z ((5761.33 337624.31 22.85, 5761.531 ...
# 1  POLYGON Z ((5863.551 337489.876 37.305, 5863.3...
# 2  POLYGON Z ((5842.86 337515.031 18.898, 5839.19...
# 3  POLYGON Z ((5794.375 337883.508 16.65, 5790.93...
# 4  POLYGON Z ((5918.127 337628.663 34.114, 5914.8...
#                                   object_id  height
# 0  UUID_LOD2_022541-f8d0017e-4c7f-4864-b562   20.96  \
# 1  UUID_LOD2_022542-7b4a1321-fecb-455c-813c   19.38
# 2  UUID_LOD2_022556-ecf52deb-01d5-409c-afa3   19.70
# 3  UUID_LOD2_022559-4c9284e2-834a-436e-866a   20.23
# 4  UUID_LOD2_022576-8c480dcd-e87b-4043-ae9e   20.59
#
#                                             geometry
# 0  POLYGON Z ((5542.37 338216.78 35.106, 5543.06 ...
# 1  POLYGON Z ((5551.261 338210.551 31.453, 5553.3...
# 2  POLYGON Z ((5753.716 338076.533 29.659, 5753.6...
# 3  POLYGON Z ((5565.416 338317.964 30.546, 5561.9...
# 4  POLYGON Z ((5644.022 338185.412 35.179, 5645.4...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 111077.gml
#                                   object_id  height
# 0  UUID_LOD2_005301-8f4d2816-4358-4bb3-a01b    7.85  \
# 1  UUID_LOD2_005312-fbc005ea-edd8-4fe4-a937   24.90
# 2  UUID_LOD2_005335-799fc1a4-44d1-4e14-911d   23.75
# 3  UUID_LOD2_116628-7b7f2495-f398-4976-ab9b    5.50
#
#                                             geometry
# 0  POLYGON Z ((5783.46 339121.95 2.109, 5785.44 3...
# 1  POLYGON Z ((5560.382 339422.766 24.308, 5566.4...
# 2  POLYGON Z ((5583.621 339485.588 24.393, 5581.7...
# 3  POLYGON Z ((5475.568 339403.891 14.854, 5470.8...
#                                   object_id  height
# 0  UUID_LOD2_004927-c042caa8-a660-4906-b4c2   25.34  \
# 1  UUID_LOD2_004928-a596f556-fbd6-49f8-8dc7   23.83
# 2  UUID_LOD2_004941-08d4238e-66df-4c57-85a3   22.35
# 3  UUID_LOD2_004966-335e6afd-97d6-4929-b0ac   19.67
# 4  UUID_LOD2_004967-8abb3d1d-fbca-4f77-8295   19.47
#
#                                             geometry
# 0  POLYGON Z ((5617.834 339728.887 28.479, 5617.9...
# 1  POLYGON Z ((5557.118 339912.621 24.437, 5553.8...
# 2  POLYGON Z ((5556.076 339946.945 4.19, 5560.204...
# 3  POLYGON Z ((5676.4 339709.82 4.229, 5690.79 33...
# 4  POLYGON Z ((5665.07 339693.953 23.62, 5665.041...
#                                   object_id  height
# 0  UUID_LOD2_105772-e439805f-3f19-4f58-af17    5.64  \
# 1  UUID_LOD2_105775-b5ebc4ee-4b40-40ca-9d51    5.57
# 2  UUID_LOD2_106973-fd55cc9c-d316-40d0-8191    4.22
# 3  UUID_LOD2_114190-07306804-cf43-4744-8e4b    3.68
# 4  UUID_LOD2_115021-aa0b073a-d470-4f7f-80f5    3.18
#
#                                             geometry
# 0  POLYGON Z ((5783.58 340292.4 6.056, 5787.286 3...
# 1  POLYGON Z ((5785.876 340266.338 7.22, 5788.238...
# 2  POLYGON Z ((5800.14 340265.49 4.941, 5800.274 ...
# 3  POLYGON Z ((5818.65 340283.8 4.764, 5821.438 3...
# 4  POLYGON Z ((5803.029 340252.086 5.69, 5800.373...
# Empty DataFrame
# Columns: []
# Index: []
# No data for specific rooftype in file 111082.gml
#                                   object_id  height
# 0  UUID_LOD2_107096-03d1a832-e8e9-4bca-aa55    5.87  \
#
#                                             geometry
# 0  POLYGON Z ((5688.231 342102.19 9.3, 5688.11 34...
# CPU times: user 5min 57s, sys: 3.36 s, total: 6min
# Wall time: 13min 48s
